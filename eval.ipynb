# %%
# %run TrackEval/scripts/run_kitti_mots.py --USE_PARALLEL False --METRICS HOTA --TRACKERS_TO_EVAL sam
# Out:
# Eval Config:
# USE_PARALLEL         : False
# NUM_PARALLEL_CORES   : 8
# BREAK_ON_ERROR       : True
# RETURN_ON_ERROR      : False
# LOG_ON_ERROR         : C:\Users\Kevin\Documents\Master Related\IS\Thesis\project\TrackEval\error_log.txt
# PRINT_RESULTS        : True
# PRINT_ONLY_COMBINED  : False
# PRINT_CONFIG         : True
# TIME_PROGRESS        : True
# DISPLAY_LESS_PROGRESS : False
# OUTPUT_SUMMARY       : True
# OUTPUT_EMPTY_CLASSES : True
# OUTPUT_DETAILED      : True
# PLOT_CURVES          : True
#
# KittiMOTS Config:
# PRINT_CONFIG         : True
# GT_FOLDER            : C:\Users\Kevin\Documents\Master Related\IS\Thesis\project\TrackEval\data/gt/kitti/kitti_mots_val
# TRACKERS_FOLDER      : C:\Users\Kevin\Documents\Master Related\IS\Thesis\project\TrackEval\data/trackers/kitti/kitti_mots_val
# OUTPUT_FOLDER        : None
# TRACKERS_TO_EVAL     : ['sam']
# CLASSES_TO_EVAL      : ['car', 'pedestrian']
# SPLIT_TO_EVAL        : val
# INPUT_AS_ZIP         : False
# TRACKER_SUB_FOLDER   : data
# OUTPUT_SUB_FOLDER    :
# TRACKER_DISPLAY_NAMES : None
# SEQMAP_FOLDER        : None
# SEQMAP_FILE          : None
# SEQ_INFO             : None
# GT_LOC_FORMAT        : {gt_folder}/label_02/{seq}.txt
#
# Evaluating 1 tracker(s) on 9 sequence(s) for 2 class(es) on KittiMOTS dataset using the following metrics: HOTA, Count
#
#
# Evaluating sam
#
#     KittiMOTS.get_raw_seq_data(sam, 0002)                                  0.0961 sec
#     KittiMOTS.get_preprocessed_seq_data(car)                               0.0249 sec
#     HOTA.eval_sequence()                                                   0.0350 sec
#     Count.eval_sequence()                                                  0.0000 sec
#     KittiMOTS.get_preprocessed_seq_data(pedestrian)                        0.0140 sec
#     HOTA.eval_sequence()                                                   0.0000 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 37 eval_sequence(0002, sam)                                               0.1709 sec
#     KittiMOTS.get_raw_seq_data(sam, 0006)                                  0.0592 sec
#     KittiMOTS.get_preprocessed_seq_data(car)                               0.0264 sec
#     HOTA.eval_sequence()                                                   0.0385 sec
#     Count.eval_sequence()                                                  0.0000 sec
#     KittiMOTS.get_preprocessed_seq_data(pedestrian)                        0.0136 sec
#     HOTA.eval_sequence()                                                   0.0000 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 38 eval_sequence(0006, sam)                                               0.1385 sec
#     KittiMOTS.get_raw_seq_data(sam, 0007)                                  0.3727 sec
#     KittiMOTS.get_preprocessed_seq_data(car)                               0.0769 sec
#     HOTA.eval_sequence()                                                   0.1142 sec
#     Count.eval_sequence()                                                  0.0000 sec
#     KittiMOTS.get_preprocessed_seq_data(pedestrian)                        0.0443 sec
#     HOTA.eval_sequence()                                                   0.0000 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 39 eval_sequence(0007, sam)                                               0.6102 sec
#     KittiMOTS.get_raw_seq_data(sam, 0008)                                  0.0908 sec
#     KittiMOTS.get_preprocessed_seq_data(car)                               0.0377 sec
#     HOTA.eval_sequence()                                                   0.0617 sec
#     Count.eval_sequence()                                                  0.0000 sec
#     KittiMOTS.get_preprocessed_seq_data(pedestrian)                        0.0205 sec
#     HOTA.eval_sequence()                                                   0.0000 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 40 eval_sequence(0008, sam)                                               0.2114 sec
#     KittiMOTS.get_raw_seq_data(sam, 0010)                                  0.0562 sec
#     KittiMOTS.get_preprocessed_seq_data(car)                               0.0279 sec
#     HOTA.eval_sequence()                                                   0.0504 sec
#     Count.eval_sequence()                                                  0.0000 sec
#     KittiMOTS.get_preprocessed_seq_data(pedestrian)                        0.0173 sec
#     HOTA.eval_sequence()                                                   0.0000 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 41 eval_sequence(0010, sam)                                               0.1525 sec
#     KittiMOTS.get_raw_seq_data(sam, 0013)                                  0.0528 sec
#     KittiMOTS.get_preprocessed_seq_data(car)                               0.0230 sec
#     HOTA.eval_sequence()                                                   0.0103 sec
#     Count.eval_sequence()                                                  0.0000 sec
#     KittiMOTS.get_preprocessed_seq_data(pedestrian)                        0.0217 sec
#     HOTA.eval_sequence()                                                   0.0000 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 42 eval_sequence(0013, sam)                                               0.1086 sec
#     KittiMOTS.get_raw_seq_data(sam, 0014)                                  0.0444 sec
#     KittiMOTS.get_preprocessed_seq_data(car)                               0.0114 sec
#     HOTA.eval_sequence()                                                   0.0174 sec
#     Count.eval_sequence()                                                  0.0000 sec
#     KittiMOTS.get_preprocessed_seq_data(pedestrian)                        0.0063 sec
#     HOTA.eval_sequence()                                                   0.0000 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 43 eval_sequence(0014, sam)                                               0.0800 sec
#     KittiMOTS.get_raw_seq_data(sam, 0016)                                  0.1451 sec
#     KittiMOTS.get_preprocessed_seq_data(car)                               0.0236 sec
#     HOTA.eval_sequence()                                                   0.0363 sec
#     Count.eval_sequence()                                                  0.0000 sec
#     KittiMOTS.get_preprocessed_seq_data(pedestrian)                        0.0155 sec
#     HOTA.eval_sequence()                                                   0.0000 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 44 eval_sequence(0016, sam)                                               0.2216 sec
#     KittiMOTS.get_raw_seq_data(sam, 0018)                                  0.1430 sec
#     KittiMOTS.get_preprocessed_seq_data(car)                               0.0375 sec
#     HOTA.eval_sequence()                                                   0.0546 sec
#     Count.eval_sequence()                                                  0.0000 sec
#     KittiMOTS.get_preprocessed_seq_data(pedestrian)                        0.0197 sec
#     HOTA.eval_sequence()                                                   0.0000 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 45 eval_sequence(0018, sam)                                               0.2562 sec
#
# All sequences for sam finished in 1.95 seconds
#
# HOTA: sam-car                      HOTA      DetA      AssA      DetRe     DetPr     AssRe     AssPr     LocA      OWTA      HOTA(0)   LocA(0)   HOTALocA(0)
# 0002                               52.418    58.201    48.39     68.526    73.143    49.914    89.252    85.029    57.234    61.986    79.602    49.342
# 0006                               82.536    86.478    78.918    92.071    89.569    80.299    94.724    92.036    85.239    89.077    91.503    81.508
# 0007                               76.985    78.683    75.524    87.642    85.521    77.776    92.052    91.026    81.348    85.622    88.297    75.602
# 0008                               74.835    83.28     67.574    87.913    88.252    68.83     94.321    89.665    77.02     83.084    88.705    73.7
# 0010                               80.571    85.752    75.874    90.715    89.087    76.451    96.01     90.776    82.948    87.704    90.047    78.975
# 0013                               48.445    33.638    73.151    79.971    35.543    74.639    94.959    86.701    75.022    55.247    83.198    45.964
# 0014                               50.629    62.434    42.333    68.398    80.089    44.7      88.731    85.285    53.332    59.792    80.188    47.946
# 0016                               36.251    67.457    20.054    76.164    77.749    20.216    90.298    85.753    38.741    42.188    82.929    34.986
# 0018                               79.711    81.746    78.199    86.393    89.97     80.923    94.406    91.057    82.106    89.061    89.078    79.334
# COMBINED                           70.341    75.514    66.174    83.516    84.271    68.061    93.115    89.495    74.208    78.692    86.997    68.46
# Count: sam-car                     Dets      GT_Dets   IDs       GT_IDs
# 0002                               846       903       124       15
# 0006                               552       537       48        11
# 0007                               2314      2258      306       53
# 0008                               1038      1042      109       21
# 0010                               613       602       70        13
# 0013                               81        36        36        2
# 0014                               392       459       116       14
# 0016                               817       834       64        4
# 0018                               1304      1358      69        18
# COMBINED                           7957      8029      942       151
#
# HOTA: sam-pedestrian               HOTA      DetA      AssA      DetRe     DetPr     AssRe     AssPr     LocA      OWTA      HOTA(0)   LocA(0)   HOTALocA(0)
# 0002                               0         0         0         0         0         0         0         100       0         0         100       0
# 0006                               0         0         0         0         0         0         0         100       0         0         100       0
# 0007                               0         0         0         0         0         0         0         100       0         0         100       0
# 0008                               0         0         0         0         0         0         0         100       0         0         100       0
# 0010                               0         0         0         0         0         0         0         100       0         0         100       0
# 0013                               0         0         0         0         0         0         0         100       0         0         100       0
# 0014                               0         0         0         0         0         0         0         100       0         0         100       0
# 0016                               0         0         0         0         0         0         0         100       0         0         100       0
# 0018                               0         0         0         0         0         0         0         100       0         0         100       0
# COMBINED                           0         0         0         0         0         0         0         100       0         0         100       0
#
# Count: sam-pedestrian              Dets      GT_Dets   IDs       GT_IDs
# 0002                               0         180       0         1
# 0006                               0         0         0         0
# 0007                               0         67        0         2
# 0008                               0         0         0         0
# 0010                               0         55        0         2
# 0013                               0         919       0         42
# 0014                               0         121       0         2
# 0016                               0         2005      0         19
# 0018                               0         0         0         0
# COMBINED                           0         3347      0         68
#
# Timing analysis:
# KittiMOTS.get_raw_seq_data                                             4.9858 sec
# KittiMOTS.get_preprocessed_seq_data                                    2.3763 sec
# HOTA.eval_sequence                                                     2.6268 sec
# Count.eval_sequence                                                    0.0001 sec
# eval_sequence                                                          10.0327 sec
# Evaluator.evaluate                                                     11.6271 sec

# %%
# %run TrackEval/scripts/run_kitti_mots.py --USE_PARALLEL False --METRICS HOTA --TRACKERS_TO_EVAL track_rcnn
# Out:
# Eval Config:
# USE_PARALLEL         : False
# NUM_PARALLEL_CORES   : 8
# BREAK_ON_ERROR       : True
# RETURN_ON_ERROR      : False
# LOG_ON_ERROR         : C:\Users\Kevin\Documents\Master Related\IS\Thesis\project\TrackEval\error_log.txt
# PRINT_RESULTS        : True
# PRINT_ONLY_COMBINED  : False
# PRINT_CONFIG         : True
# TIME_PROGRESS        : True
# DISPLAY_LESS_PROGRESS : False
# OUTPUT_SUMMARY       : True
# OUTPUT_EMPTY_CLASSES : True
# OUTPUT_DETAILED      : True
# PLOT_CURVES          : True
#
# KittiMOTS Config:
# PRINT_CONFIG         : True
# GT_FOLDER            : C:\Users\Kevin\Documents\Master Related\IS\Thesis\project\TrackEval\data/gt/kitti/kitti_mots_val
# TRACKERS_FOLDER      : C:\Users\Kevin\Documents\Master Related\IS\Thesis\project\TrackEval\data/trackers/kitti/kitti_mots_val
# OUTPUT_FOLDER        : None
# TRACKERS_TO_EVAL     : ['track_rcnn']
# CLASSES_TO_EVAL      : ['car', 'pedestrian']
# SPLIT_TO_EVAL        : val
# INPUT_AS_ZIP         : False
# TRACKER_SUB_FOLDER   : data
# OUTPUT_SUB_FOLDER    :
# TRACKER_DISPLAY_NAMES : None
# SEQMAP_FOLDER        : None
# SEQMAP_FILE          : None
# SEQ_INFO             : None
# GT_LOC_FORMAT        : {gt_folder}/label_02/{seq}.txt
#
# Evaluating 1 tracker(s) on 9 sequence(s) for 2 class(es) on KittiMOTS dataset using the following metrics: HOTA, Count
#
#
# Evaluating track_rcnn
#
#     KittiMOTS.get_raw_seq_data(track_rcnn, 0002)                           0.0822 sec
#     KittiMOTS.get_preprocessed_seq_data(car)                               0.0288 sec
#     HOTA.eval_sequence()                                                   0.0360 sec
#     Count.eval_sequence()                                                  0.0000 sec
#     KittiMOTS.get_preprocessed_seq_data(pedestrian)                        0.0183 sec
#     HOTA.eval_sequence()                                                   0.0234 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 28 eval_sequence(0002, track_rcnn)                                        0.1897 sec
#     KittiMOTS.get_raw_seq_data(track_rcnn, 0006)                           0.0471 sec
#     KittiMOTS.get_preprocessed_seq_data(car)                               0.0245 sec
#     HOTA.eval_sequence()                                                   0.0405 sec
#     Count.eval_sequence()                                                  0.0000 sec
#     KittiMOTS.get_preprocessed_seq_data(pedestrian)                        0.0148 sec
#     HOTA.eval_sequence()                                                   0.0000 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 29 eval_sequence(0006, track_rcnn)                                        0.1277 sec
#     KittiMOTS.get_raw_seq_data(track_rcnn, 0007)                           0.2075 sec
#     KittiMOTS.get_preprocessed_seq_data(car)                               0.0717 sec
#     HOTA.eval_sequence()                                                   0.1155 sec
#     Count.eval_sequence()                                                  0.0000 sec
#     KittiMOTS.get_preprocessed_seq_data(pedestrian)                        0.0457 sec
#     HOTA.eval_sequence()                                                   0.0189 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 30 eval_sequence(0007, track_rcnn)                                        0.4610 sec
#     KittiMOTS.get_raw_seq_data(track_rcnn, 0008)                           0.0759 sec
#     KittiMOTS.get_preprocessed_seq_data(car)                               0.0377 sec
#     HOTA.eval_sequence()                                                   0.0644 sec
#     Count.eval_sequence()                                                  0.0000 sec
#     KittiMOTS.get_preprocessed_seq_data(pedestrian)                        0.0234 sec
#     HOTA.eval_sequence()                                                   0.0000 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 31 eval_sequence(0008, track_rcnn)                                        0.2023 sec
#     KittiMOTS.get_raw_seq_data(track_rcnn, 0010)                           0.0467 sec
#     KittiMOTS.get_preprocessed_seq_data(car)                               0.0267 sec
#     HOTA.eval_sequence()                                                   0.0513 sec
#     Count.eval_sequence()                                                  0.0000 sec
#     KittiMOTS.get_preprocessed_seq_data(pedestrian)                        0.0174 sec
#     HOTA.eval_sequence()                                                   0.0069 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 32 eval_sequence(0010, track_rcnn)                                        0.1498 sec
#     KittiMOTS.get_raw_seq_data(track_rcnn, 0013)                           0.1274 sec
#     KittiMOTS.get_preprocessed_seq_data(car)                               0.0210 sec
#     HOTA.eval_sequence()                                                   0.0103 sec
#     Count.eval_sequence()                                                  0.0000 sec
#     KittiMOTS.get_preprocessed_seq_data(pedestrian)                        0.0327 sec
#     HOTA.eval_sequence()                                                   0.0419 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 33 eval_sequence(0013, track_rcnn)                                        0.2342 sec
#     KittiMOTS.get_raw_seq_data(track_rcnn, 0014)                           0.0418 sec
#     KittiMOTS.get_preprocessed_seq_data(car)                               0.0103 sec
#     HOTA.eval_sequence()                                                   0.0170 sec
#     Count.eval_sequence()                                                  0.0000 sec
#     KittiMOTS.get_preprocessed_seq_data(pedestrian)                        0.0082 sec
#     HOTA.eval_sequence()                                                   0.0086 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 34 eval_sequence(0014, track_rcnn)                                        0.0863 sec
#     KittiMOTS.get_raw_seq_data(track_rcnn, 0016)                           0.2021 sec
#     KittiMOTS.get_preprocessed_seq_data(car)                               0.0198 sec
#     HOTA.eval_sequence()                                                   0.0319 sec
#     Count.eval_sequence()                                                  0.0000 sec
#     KittiMOTS.get_preprocessed_seq_data(pedestrian)                        0.0274 sec
#     HOTA.eval_sequence()                                                   0.0344 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 35 eval_sequence(0016, track_rcnn)                                        0.3168 sec
#     KittiMOTS.get_raw_seq_data(track_rcnn, 0018)                           0.1164 sec
#     KittiMOTS.get_preprocessed_seq_data(car)                               0.0348 sec
#     HOTA.eval_sequence()                                                   0.0512 sec
#     Count.eval_sequence()                                                  0.0000 sec
#     KittiMOTS.get_preprocessed_seq_data(pedestrian)                        0.0178 sec
#     HOTA.eval_sequence()                                                   0.0000 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 36 eval_sequence(0018, track_rcnn)                                        0.2211 sec
#
# All sequences for track_rcnn finished in 1.99 seconds
#
# HOTA: track_rcnn-car               HOTA      DetA      AssA      DetRe     DetPr     AssRe     AssPr     LocA      OWTA      HOTA(0)   LocA(0)   HOTALocA(0)
# 0002                               52.787    65.291    43.399    69.686    82.042    51.821    61.974    84.8      54.797    62.881    81.645    51.34
# 0006                               78.965    85.707    72.95     88.778    90.291    81.584    81.96     90.01     80.465    87.251    89.178    77.809
# 0007                               79.12     85.239    73.481    88.32     90.813    88.939    76.917    90.331    80.547    88.195    89.212    78.681
# 0008                               76.618    83.444    70.738    86.064    88.354    77.577    84.846    87.802    77.953    87.896    86.511    76.039
# 0010                               83.397    84.932    82.074    87.34     90.653    89.449    84.798    89.487    84.652    92.835    88.548    82.204
# 0013                               66.232    65.504    68.806    73.538    77.864    71.565    90.887    85.561    70.541    78.064    83.409    65.113
# 0014                               57.45     66.888    49.758    71.62     81.979    73.316    59.407    84.701    59.636    70.878    81.113    57.491
# 0016                               38.33     50.469    29.77     53.383    79.502    31.983    69.572    83.595    39.614    46.827    79.304    37.135
# 0018                               81.211    83.602    79.067    87.28     89.185    86.835    83.663    89.293    83.063    91.498    87.782    80.319
# COMBINED                           72.263    77.385    67.823    81.063    87.834    78.387    77.78     88.346    74.113    82.112    86.547    71.065
# Count: track_rcnn-car              Dets      GT_Dets   IDs       GT_IDs
# 0002                               767       903       20        15
# 0006                               528       537       17        11
# 0007                               2196      2258      53        53
# 0008                               1015      1042      21        21
# 0010                               580       602       11        13
# 0013                               34        36        6         2
# 0014                               401       459       12        14
# 0016                               560       834       17        4
# 0018                               1329      1358      16        18
# COMBINED                           7410      8029      173       151
#
# HOTA: track_rcnn-pedestrian        HOTA      DetA      AssA      DetRe     DetPr     AssRe     AssPr     LocA      OWTA      HOTA(0)   LocA(0)   HOTALocA(0)
# 0002                               48.778    53.046    44.856    55.468    68.857    46.735    69.101    74.725    49.819    72.283    68.818    49.744
# 0006                               0         0         0         0         0         0         0         100       0         0         100       0
# 0007                               36.992    35.644    38.511    39.906    63.659    39.982    74.291    78.136    39.152    50.992    73.054    37.252
# 0008                               0         0         0         0         0         0         0         100       0         0         100       0
# 0010                               25.972    19.464    34.691    19.713    67.763    35.579    67.965    76.093    26.127    39.156    66.608    26.081
# 0013                               53.544    63.494    45.68     68.925    73.998    67.677    51.618    79.266    56.004    71.404    74.603    53.27
# 0014                               26.966    37.085    19.77     44.15     46.861    26.215    34.756    69.151    29.529    58.581    49.575    29.042
# 0016                               36.606    55.474    24.363    59.079    75.208    38.453    38.152    79.57     37.882    48.954    74.682    36.56
# 0018                               0         0         0         0         0         0         0         100       0         0         100       0
# COMBINED                           42.106    54.908    32.683    60.018    71.948    48.435    45.231    78.585    44.171    57.285    73.272    41.974
#
# Count: track_rcnn-pedestrian       Dets      GT_Dets   IDs       GT_IDs
# 0002                               145       180       2         1
# 0006                               1         0         1         0
# 0007                               42        67        6         2
# 0008                               43        0         6         0
# 0010                               16        55        2         2
# 0013                               856       919       29        42
# 0014                               114       121       5         2
# 0016                               1575      2005      21        19
# 0018                               0         0         0         0
# COMBINED                           2792      3347      72        68
#
# Timing analysis:
# KittiMOTS.get_raw_seq_data                                             3.9256 sec
# KittiMOTS.get_preprocessed_seq_data                                    1.9143 sec
# HOTA.eval_sequence                                                     2.2084 sec
# Count.eval_sequence                                                    0.0001 sec
# eval_sequence                                                          8.0828 sec
# Evaluator.evaluate                                                     9.4276 sec

# %%
import numpy as np
import os
import cv2
from pycocotools import mask as cocomask
from tqdm import tqdm

def calculate_mask_iou(mask1, mask2):

    mask1_bool = mask1.astype(bool)
    mask2_bool = mask2.astype(bool)

    intersection = np.sum(mask1_bool & mask2_bool)
    union = np.sum(mask1_bool | mask2_bool)

    if union == 0:
        return 0.0
    return intersection / union

def calculate_mask_dice(mask1, mask2):

    mask1_bool = mask1.astype(bool)
    mask2_bool = mask2.astype(bool)

    intersection = np.sum(mask1_bool & mask2_bool)
    # The sum of elements in both masks (2 * intersection + (union - intersection))
    total_elements = np.sum(mask1_bool) + np.sum(mask2_bool)

    if total_elements == 0:
        return 0.0
    return (2.0 * intersection) / total_elements

def parse_kitti_mots_file(filepath):
    """
    Parses a KITTI MOTS .txt file and returns a dictionary of masks per frame.

    Args:
        filepath (str): Path to the KITTI MOTS .txt file.

    Returns:
        dict: A dictionary where keys are frame numbers (int) and values are
              lists of dictionaries. Each inner dictionary contains 'mask',
              'obj_id', 'cls_id', 'height', 'width'.
    """
    frames_data = {}
    with open(filepath, 'r') as f:
        for line in f:
            parts = line.strip().split(' ')

            if len(parts) < 6: # Ensure correct data/line structure
                print(f"Incorrect data, skipping line in {filepath}: {line.strip()}")
                continue
            frame_num = int(parts[0])
            obj_id = int(parts[1])
            cls_id = int(parts[2])
            height = int(parts[3])
            width = int(parts[4])
            rle_str = parts[5]

            # Decode RLE string to mask
            rle = {'size': [height, width], 'counts': rle_str.encode('utf-8')}
            
            # Error handling for bad rle string
            try:
                mask = cocomask.decode(rle)
            except Exception as e:
                print(f"Could not decode RLE in frame {frame_num} of {filepath}: {e}. Skipping mask.")
                continue # Skip

            if frame_num not in frames_data:
                frames_data[frame_num] = []
            frames_data[frame_num].append({
                'mask': mask.astype(bool),
                'obj_id': obj_id,
                'cls_id': cls_id,
                'height': height,
                'width': width
            })
    return frames_data

def evaluate_segmentation_quality(predictions_root, ground_truth_root, target_class_id=1):
    #Evaluates segmentation quality (IoU and Dice) for all 'car' instances.

    all_iou_scores = []
    all_dice_scores = []

    prediction_files = sorted([f for f in os.listdir(predictions_root) if f.endswith('.txt')])

    # Iterate through prediction files and check for corresponding ground truth files
    for pred_filename in tqdm(prediction_files, desc="Evaluating files"):
        pred_file_path = os.path.join(predictions_root, pred_filename)
        gt_file_path = os.path.join(ground_truth_root, pred_filename)

        # Only evaluate if both prediction and ground truth files exist
        if not os.path.exists(pred_file_path):
            print(f"Warning: Prediction file not found: {pred_file_path}. Skipping.")
            continue
        if not os.path.exists(gt_file_path):
            print(f"Warning: Corresponding ground truth file not found for {pred_filename}: {gt_file_path}. Skipping.")
            continue

        predicted_frames = parse_kitti_mots_file(pred_file_path)
        gt_frames = parse_kitti_mots_file(gt_file_path)

        # Iterate through frames present in ground truth
        for frame_num in sorted(gt_frames.keys()):
            gt_objects = [obj for obj in gt_frames[frame_num] if obj['cls_id'] == target_class_id]
            predicted_objects = predicted_frames.get(frame_num, [])

            matched_gt_indices = set()

            for pred_obj in predicted_objects:
                # Only evaluate if the predicted object is of the target class (e.g., 'car')
                if pred_obj['cls_id'] != target_class_id:
                    continue

                best_iou = 0.0
                best_gt_idx = -1

                for gt_idx, gt_obj in enumerate(gt_objects):
                    if gt_idx in matched_gt_indices:
                        continue # Skip already matched GT objects

                    # Calculate IoU for matching
                    iou = calculate_mask_iou(pred_obj['mask'], gt_obj['mask'])

                    if iou > best_iou: # Find the best matching ground truth for this prediction
                        best_iou = iou
                        best_gt_idx = gt_idx

                # If a good enough match is found, record the scores
                if best_iou > 0.5: # Tune this threshold for matching
                    all_iou_scores.append(best_iou)
                    all_dice_scores.append(calculate_mask_dice(pred_obj['mask'], gt_objects[best_gt_idx]['mask']))
                    matched_gt_indices.add(best_gt_idx)

    return all_iou_scores, all_dice_scores

# %%
if __name__ == "__main__":
    
    predictions_base_dir = "TrackEval/data/trackers/kitti/kitti_mots_val/sam/data"
    ground_truth_base_dir = "TrackEval/data/gt/kitti/kitti_mots_val/label_02"

    car_class_id = 1

    print(f"Evaluation for class ID: {car_class_id} ('Car')...")
    iou_scores, dice_scores = evaluate_segmentation_quality(
        predictions_base_dir,
        ground_truth_base_dir,
        target_class_id=car_class_id
    )

    if iou_scores:
        mean_iou = np.mean(iou_scores)
        mean_dice = np.mean(dice_scores)
        print(f"Evaluation Results for Class ID {car_class_id} ('Car'):")
        print(f"Total matched instances: {len(iou_scores)}")
        print(f"Mean IoU: {mean_iou:.4f}")
        print(f"Mean Dice Coefficient(F-1 Score): {mean_dice:.4f}")
    else:
        print("Failed")
# Out:
# Starting segmentation evaluation for class ID: 1 ('Car')...
# Evaluating files: 100%|██████████| 9/9 [00:28<00:00,  3.17s/it]
# Evaluation Results for Class ID 1 ('Car'):
#   Total matched instances: 7332
#   Mean IoU: 0.8857
#   Mean Dice Coefficient: 0.9368
